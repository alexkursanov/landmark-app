# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import py_tps as tps
from PIL import Image

from torch import nn
from torchvision import datasets, models, transforms
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms.functional as TF

import time
import pickle

import scipy.stats as stats

# %%
class LandmarksDataset():
    def __init__(self): # инициация программы и установление основных значений
        self.drive_dir = '../data/interin' # <- Путь до папки где лежит папка на которых будим учится
        self.image_dir = 'Ac_Fom_2022_WM_scale' # <- Название папки с исходными фото и файлом *.TPS
        self.tps_file_name = 'Ac_Fom2022WM_FL_scale.TPS' # <- Название файла *.TPS
        self.tps_file = tps.TPSFile.read_file(os.path.join(self.drive_dir, self.image_dir, self.tps_file_name))
        self.transform = False # <- Нужно ли трасформировать исходные изображения, если нужно параметры для трансформации в поле self.params
        self.params = {'rotation_range':[40], 'zoom_range':[0.7,1.3], 'height_shift_range':[-0.05, 0.05], 'width_shift_range':[-0.05, 0.05], 'contrast_range':1}

    def __getitem__(self, index): # получение изображения и коррдинат точек к нему, случайное изменение изображения, перевод изображения в формат torch

        # Загрузка фото и его перевод в массив numpy, определение размера в пиксилях
        image = Image.open(os.path.join(self.drive_dir, self.image_dir, self.tps_file.images[index].image))
        image_array = np.array(image)
        image_shape = image_array.shape
    
        # Загрузка ландмарок и их зеркальное отображение по вертикали
        landmarks = self.tps_file.images[index].landmarks.points
        landmarks_flip = np.zeros(landmarks.shape)
        landmarks_flip[:,0] = landmarks[:,0]
        landmarks_flip[:,1] = image_shape[0] - landmarks[:,1]
        params = self.params

        # Масштабирование исходного изображения и его нормировка
        img_shape = image.size
        image = TF.resize(image, (224,224))
        image = TF.to_tensor(image)
        image = TF.normalize(image, [0.5],[0.5])

        # Масштабирование ландмарок и их нормировка
        landmarks_flip = torch.tensor(landmarks_flip)/torch.tensor([img_shape[0],img_shape[1]])
        landmarks_flip = landmarks_flip.clone().detach() - 0.5

        return image, landmarks_flip

    def __len__(self):
        return len(self.tps_file.images)

# %%
class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        for t, m ,s in zip(tensor, self.mean, self.std):
          t.mul_(s).add_(m)
        return tensor

# %%
dataset = LandmarksDataset()
image, landmarks = dataset[1]

unorm = UnNormalize(mean= (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5))
image = unorm(image)
image = image.permute(1,2,0).numpy()

landmarks = (landmarks +0.5)*torch.tensor([224,224])
plt.imshow(image)
plt.scatter(landmarks[:,0],landmarks[:,1], color = 'red' , s = 5)
plt.show()

# %%
class resnet50(nn.Module):
    def __init__(self, num_classes = 38): # Установление параметров модели нейросети 42 если 21 точка и 38 если 19 точек
        super().__init__()
        self.model_name = 'resnet50'
        self.model = models.resnet50(pretrained =True)
        self.model.conv1 = nn.Conv2d(3, 64, kernel_size = 7, stride =2, padding=3, bias=False)
        self.model.fc = nn.Linear(self.model.fc.in_features, num_classes)
    def forward(self, x):
        x = self.model(x)
        return x

# %%
len_valid_test_set = int(0.1*len(dataset)) # 80% тренировочная выборка, 10% валидационная выборка, 10% тестовая выборка

len_train_set = len(dataset) - len_valid_test_set*2

print("Длина тренировочной выборки {}".format(len_train_set))
print("Длина валидационной выборки {}".format(len_valid_test_set))
print("Длина тестовой выборки {}".format(len_valid_test_set))

train_dataset , valid_dataset, test_dataset  = torch.utils.data.random_split(dataset , [len_train_set, len_valid_test_set, len_valid_test_set], generator=torch.Generator().manual_seed(38))

# Смешивание и объединение наборов данных
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=24, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=20, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=None,batch_sampler=None, shuffle=False)
# Out:
# Длина тренировочной выборки 225
# Длина валидационной выборки 28
# Длина тестовой выборки 28

# %%
def print_overwrite(step, total_step, loss, operation):
    sys.stdout.write('\r')
    if operation == 'train':
        sys.stdout.write("Train Steps: %d/%d  Loss: %.8f " % (step, total_step, loss))
    else:
        sys.stdout.write("Valid Steps: %d/%d  Loss: %.8f " % (step, total_step, loss))

    sys.stdout.flush()

# %%
network = resnet50()
network.load_state_dict(torch.load('../data/interin/Ac_Fom_2022_WM_scale/restnet50_0_0.pth'))
network.cpu()
torch.autograd.set_detect_anomaly(True)
# Out:
# C:\Users\Alexander\projects\landmark-app\env\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Alexander\projects\landmark-app\env\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# C:\Users\Alexander\AppData\Local\Temp\ipykernel_11036\2950689968.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   network.load_state_dict(torch.load('../data/interin/Ac_Fom_2022_WM_scale/restnet50_0_0.pth'))

# %%
loss_list = {'train': [], 'val':[], 'time': []}

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(network.parameters(), lr=0.000001)

# %%
num_epohs = 500
loss_dic = {'train':[],'valid':[],'time':[]}

# %%
start_time = time.time()
loss_valid_min = np.inf
for epoh in range(1,num_epohs+1):
  loss_train = 0
  loss_valid = 0
  running_loss = 0

  network.train()

  for step in range (1, len(iter(train_loader))+1):
    images, landmarks = next(iter(train_loader))

    images = images.cpu()
    landmarks = landmarks.view(landmarks.size(0),-1).cpu()
    landmarks = landmarks.clone().to(torch.float32)

    predictions = network(images)

    optimizer.zero_grad()

    loss_train_step = criterion(predictions, landmarks)

    loss_train_step.backward()
    optimizer.step()

    loss_train = loss_train + loss_train_step.item()
    running_loss = loss_train/step

    print_overwrite(step, len(train_loader), running_loss, 'train')

  network.eval()
  with torch.no_grad():

    for step in range (1, len(iter(valid_loader))+1):

      images, landmarks = next(iter(valid_loader))

      images = images.cpu()
      landmarks = landmarks.view(landmarks.size(0),-1).cpu()
      landmarks = landmarks.clone().to(torch.float32)


      predictions = network(images)

      loss_valid_step = criterion(predictions, landmarks)

      loss_valid = loss_valid + loss_valid_step.item()
      running_loss = loss_valid/step

      print_overwrite(step, len(valid_loader), running_loss, 'valid')

  loss_train /= len(train_loader)
  loss_valid /= len(valid_loader)

  print('\n---------------------------------------------------')
  print('Эпоха: {} Train loss: {:.8f}, Valid loss: {:.8f}'.format(epoh,loss_train,loss_valid))
  print('---------------------------------------------------')

  loss_dic['train'].append(loss_train)
  loss_dic['valid'].append(loss_valid)
  loss_dic['time'].append(time.time()-start_time)

  file_dic = open('../data/interin/Ac_Fom_2022_WM_scale/restnet50_0_0.pkl', 'wb')
  pickle.dump(loss_dic, file_dic)
  file_dic.close()


  if loss_valid < loss_valid_min:
    loss_valid_min = loss_valid
    torch.save(network.state_dict(),'../data/interin/Ac_Fom_2022_WM_scale/restnet50_0_0.pth')
    print('Минимальная ошибка валидации Valid loss: {:.8f} на эпохе {}'.format(loss_valid_min,epoh))
    print('Модель сохранена')

print('Обучение завершено')
print('Всего затрачено времени: {} c.'.format(time.time()-start_time))
# Out:
# Valid Steps: 2/2  Loss: 0.00141786 0
# ---------------------------------------------------
# Эпоха: 1 Train loss: 6.20965045527555e-05, Valid loss: 0.0014178554993122816
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0014178554993122816 на эпохе 1
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00146567 8
# ---------------------------------------------------
# Эпоха: 2 Train loss: 6.82799694914138e-05, Valid loss: 0.0014656727435067296
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00142056 6
# ---------------------------------------------------
# Эпоха: 3 Train loss: 5.976016509521287e-05, Valid loss: 0.0014205611660145223
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00130169 0
# ---------------------------------------------------
# Эпоха: 4 Train loss: 6.360146107908804e-05, Valid loss: 0.001301685522776097
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.001301685522776097 на эпохе 4
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00139748 4
# ---------------------------------------------------
# Эпоха: 5 Train loss: 8.603557471360545e-05, Valid loss: 0.0013974784524179995
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00141430 6
# ---------------------------------------------------
# Эпоха: 6 Train loss: 6.466415325121489e-05, Valid loss: 0.0014143024454824626
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00135049 2
# ---------------------------------------------------
# Эпоха: 7 Train loss: 6.972048431634903e-05, Valid loss: 0.0013504874077625573
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00130439 9
# ---------------------------------------------------
# Эпоха: 8 Train loss: 6.058904946257826e-05, Valid loss: 0.001304386998526752
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00133802 0
# ---------------------------------------------------
# Эпоха: 9 Train loss: 6.77956977597205e-05, Valid loss: 0.0013380196178331971
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00134149 7
# ---------------------------------------------------
# Эпоха: 10 Train loss: 6.027482850186061e-05, Valid loss: 0.001341486582532525
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00133139 3
# ---------------------------------------------------
# Эпоха: 11 Train loss: 7.612982517457567e-05, Valid loss: 0.0013313906383700669
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00131466 3
# ---------------------------------------------------
# Эпоха: 12 Train loss: 6.713069378747605e-05, Valid loss: 0.0013146608253009617
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00135252 7
# ---------------------------------------------------
# Эпоха: 13 Train loss: 5.95663925196277e-05, Valid loss: 0.0013525221729651093
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00128085 7
# ---------------------------------------------------
# Эпоха: 14 Train loss: 6.647204390901607e-05, Valid loss: 0.0012808493338525295
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0012808493338525295 на эпохе 14
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00133875 8
# ---------------------------------------------------
# Эпоха: 15 Train loss: 6.537700828630477e-05, Valid loss: 0.0013387500657700002
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00129203 8
# ---------------------------------------------------
# Эпоха: 16 Train loss: 5.987807417113799e-05, Valid loss: 0.001292028755415231
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00130213 1
# ---------------------------------------------------
# Эпоха: 17 Train loss: 5.981112190056592e-05, Valid loss: 0.0013021306367591023
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00122874 9
# ---------------------------------------------------
# Эпоха: 18 Train loss: 7.298987511603628e-05, Valid loss: 0.0012287360150367022
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0012287360150367022 на эпохе 18
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00124307 4
# ---------------------------------------------------
# Эпоха: 19 Train loss: 8.034326383494772e-05, Valid loss: 0.0012430669157765806
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00131082 9
# ---------------------------------------------------
# Эпоха: 20 Train loss: 7.08867512003053e-05, Valid loss: 0.0013108245329931378
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00126454 9
# ---------------------------------------------------
# Эпоха: 21 Train loss: 5.9787731879623605e-05, Valid loss: 0.0012645372771658003
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00133589 0
# ---------------------------------------------------
# Эпоха: 22 Train loss: 6.379603983077686e-05, Valid loss: 0.0013358858996070921
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00131367 5
# ---------------------------------------------------
# Эпоха: 23 Train loss: 5.945236043771729e-05, Valid loss: 0.0013136735069565475
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00125921 3
# ---------------------------------------------------
# Эпоха: 24 Train loss: 7.403155104839243e-05, Valid loss: 0.0012592129642143846
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00130107 8
# ---------------------------------------------------
# Эпоха: 25 Train loss: 5.577589654421899e-05, Valid loss: 0.0013010709080845118
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00122474 2
# ---------------------------------------------------
# Эпоха: 26 Train loss: 5.191883828956634e-05, Valid loss: 0.0012247386039234698
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0012247386039234698 на эпохе 26
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00122871 6
# ---------------------------------------------------
# Эпоха: 27 Train loss: 5.195721605559811e-05, Valid loss: 0.0012287141289561987
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00124555 0
# ---------------------------------------------------
# Эпоха: 28 Train loss: 5.4504310537595305e-05, Valid loss: 0.0012455524993129075
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00128573 9
# ---------------------------------------------------
# Эпоха: 29 Train loss: 6.379331607604399e-05, Valid loss: 0.001285727135837078
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00120641 0
# ---------------------------------------------------
# Эпоха: 30 Train loss: 5.899874522583559e-05, Valid loss: 0.0012064119800925255
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0012064119800925255 на эпохе 30
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00126193 2
# ---------------------------------------------------
# Эпоха: 31 Train loss: 6.0623776880675e-05, Valid loss: 0.001261934987269342
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00122147 3
# ---------------------------------------------------
# Эпоха: 32 Train loss: 5.3833636047784236e-05, Valid loss: 0.0012214708840474486
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00125005 4
# ---------------------------------------------------
# Эпоха: 33 Train loss: 5.934413165959995e-05, Valid loss: 0.0012500483426265419
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00120278 9
# ---------------------------------------------------
# Эпоха: 34 Train loss: 6.029104806657415e-05, Valid loss: 0.0012027820339426398
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0012027820339426398 на эпохе 34
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00124715 4
# ---------------------------------------------------
# Эпоха: 35 Train loss: 7.434280996676534e-05, Valid loss: 0.0012471535592339933
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00123037 2
# ---------------------------------------------------
# Эпоха: 36 Train loss: 6.712153990520164e-05, Valid loss: 0.0012303729308769107
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00120013 3
# ---------------------------------------------------
# Эпоха: 37 Train loss: 7.833499512344133e-05, Valid loss: 0.001200126949697733
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.001200126949697733 на эпохе 37
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00126415 2
# ---------------------------------------------------
# Эпоха: 38 Train loss: 5.831818671140354e-05, Valid loss: 0.0012641498469747603
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00120042 5
# ---------------------------------------------------
# Эпоха: 39 Train loss: 5.824969193781726e-05, Valid loss: 0.0012004202581010759
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00123310 4
# ---------------------------------------------------
# Эпоха: 40 Train loss: 4.793760163011029e-05, Valid loss: 0.0012331000179983675
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00118607 5
# ---------------------------------------------------
# Эпоха: 41 Train loss: 5.604851721727755e-05, Valid loss: 0.0011860710801556706
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0011860710801556706 на эпохе 41
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00115320 8
# ---------------------------------------------------
# Эпоха: 42 Train loss: 5.267941050988156e-05, Valid loss: 0.0011532008647918701
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0011532008647918701 на эпохе 42
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00121099 3
# ---------------------------------------------------
# Эпоха: 43 Train loss: 6.403028019121848e-05, Valid loss: 0.0012109872768633068
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00121002 0
# ---------------------------------------------------
# Эпоха: 44 Train loss: 5.630272462440189e-05, Valid loss: 0.001210015732795
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00119538 5
# ---------------------------------------------------
# Эпоха: 45 Train loss: 4.495495195442345e-05, Valid loss: 0.0011953848879784346
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00112733 1
# ---------------------------------------------------
# Эпоха: 46 Train loss: 5.6907372345449404e-05, Valid loss: 0.001127334136981517
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.001127334136981517 на эпохе 46
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00112085 2
# ---------------------------------------------------
# Эпоха: 47 Train loss: 5.461853688757401e-05, Valid loss: 0.001120852364692837
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.001120852364692837 на эпохе 47
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00120728 0
# ---------------------------------------------------
# Эпоха: 48 Train loss: 5.610156840702984e-05, Valid loss: 0.001207275374326855
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00122163 0
# ---------------------------------------------------
# Эпоха: 49 Train loss: 6.080143539293204e-05, Valid loss: 0.0012216337490826845
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00122296 4
# ---------------------------------------------------
# Эпоха: 50 Train loss: 5.8343462660559454e-05, Valid loss: 0.0012229608837515116
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00116255 0
# ---------------------------------------------------
# Эпоха: 51 Train loss: 5.3602586558554324e-05, Valid loss: 0.0011625458719208837
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00117237 0
# ---------------------------------------------------
# Эпоха: 52 Train loss: 4.800195074494695e-05, Valid loss: 0.001172365853562951
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00116970 4
# ---------------------------------------------------
# Эпоха: 53 Train loss: 5.203698201512452e-05, Valid loss: 0.0011696980218403041
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00117132 7
# ---------------------------------------------------
# Эпоха: 54 Train loss: 5.6270618370035666e-05, Valid loss: 0.0011713180574588478
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00115685 6
# ---------------------------------------------------
# Эпоха: 55 Train loss: 5.025576465413906e-05, Valid loss: 0.0011568545596674085
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00120038 2
# ---------------------------------------------------
# Эпоха: 56 Train loss: 4.9820010099210775e-05, Valid loss: 0.0012003815500065684
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00115043 8
# ---------------------------------------------------
# Эпоха: 57 Train loss: 5.308432628226001e-05, Valid loss: 0.0011504256981424987
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00106658 6
# ---------------------------------------------------
# Эпоха: 58 Train loss: 5.78611532546347e-05, Valid loss: 0.0010665830923244357
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0010665830923244357 на эпохе 58
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00110637 4
# ---------------------------------------------------
# Эпоха: 59 Train loss: 5.8844584054895675e-05, Valid loss: 0.0011063668644055724
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00115087 1
# ---------------------------------------------------
# Эпоха: 60 Train loss: 4.9609951383899896e-05, Valid loss: 0.0011508718598634005
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00112048 9
# ---------------------------------------------------
# Эпоха: 61 Train loss: 5.009087253711186e-05, Valid loss: 0.001120484434068203
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00117565 9
# ---------------------------------------------------
# Эпоха: 62 Train loss: 8.339009327755776e-05, Valid loss: 0.001175649929791689
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00117382 6
# ---------------------------------------------------
# Эпоха: 63 Train loss: 5.306381099217106e-05, Valid loss: 0.0011738192406482995
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00109118 8
# ---------------------------------------------------
# Эпоха: 64 Train loss: 4.4075862388126555e-05, Valid loss: 0.0010911812423728406
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00112674 3
# ---------------------------------------------------
# Эпоха: 65 Train loss: 5.113050901854877e-05, Valid loss: 0.0011267432128079236
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00112415 2
# ---------------------------------------------------
# Эпоха: 66 Train loss: 5.891531145607587e-05, Valid loss: 0.0011241512838751078
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00113945 9
# ---------------------------------------------------
# Эпоха: 67 Train loss: 5.759036685049068e-05, Valid loss: 0.00113945227349177
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00117727 1
# ---------------------------------------------------
# Эпоха: 68 Train loss: 5.050653126090765e-05, Valid loss: 0.0011772693251259625
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00110097 2
# ---------------------------------------------------
# Эпоха: 69 Train loss: 5.6419787870254365e-05, Valid loss: 0.0011009745066985488
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00104237 0
# ---------------------------------------------------
# Эпоха: 70 Train loss: 5.760164676757995e-05, Valid loss: 0.0010423712083138525
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0010423712083138525 на эпохе 70
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00107675 5
# ---------------------------------------------------
# Эпоха: 71 Train loss: 5.1352927039260975e-05, Valid loss: 0.0010767526109702885
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00107913 3
# ---------------------------------------------------
# Эпоха: 72 Train loss: 4.6526883670594545e-05, Valid loss: 0.0010791293461807072
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00103022 5
# ---------------------------------------------------
# Эпоха: 73 Train loss: 4.844960531045217e-05, Valid loss: 0.0010302179725840688
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0010302179725840688 на эпохе 73
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00107751 4
# ---------------------------------------------------
# Эпоха: 74 Train loss: 4.504450953390915e-05, Valid loss: 0.0010775089031085372
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00112267 7
# ---------------------------------------------------
# Эпоха: 75 Train loss: 4.6873751853127035e-05, Valid loss: 0.0011226696078665555
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00114101 3
# ---------------------------------------------------
# Эпоха: 76 Train loss: 5.152520116098458e-05, Valid loss: 0.0011410120641812682
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00107021 5
# ---------------------------------------------------
# Эпоха: 77 Train loss: 5.424938353826292e-05, Valid loss: 0.0010702137951739132
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00105736 8
# ---------------------------------------------------
# Эпоха: 78 Train loss: 6.0982522700214756e-05, Valid loss: 0.001057362649589777
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00105102 6
# ---------------------------------------------------
# Эпоха: 79 Train loss: 5.3956920964992605e-05, Valid loss: 0.0010510151041671634
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00110454 0
# ---------------------------------------------------
# Эпоха: 80 Train loss: 5.420308079919778e-05, Valid loss: 0.0011045366409234703
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00105277 4
# ---------------------------------------------------
# Эпоха: 81 Train loss: 4.883746660198085e-05, Valid loss: 0.0010527660488151014
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00100268 0
# ---------------------------------------------------
# Эпоха: 82 Train loss: 4.3096656736452135e-05, Valid loss: 0.001002675446216017
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.001002675446216017 на эпохе 82
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00100211 6
# ---------------------------------------------------
# Эпоха: 83 Train loss: 5.0456938697607254e-05, Valid loss: 0.0010021086200140417
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0010021086200140417 на эпохе 83
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00107001 8
# ---------------------------------------------------
# Эпоха: 84 Train loss: 4.887505892838817e-05, Valid loss: 0.0010700142593123019
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00105222 0
# ---------------------------------------------------
# Эпоха: 85 Train loss: 4.2000961911980994e-05, Valid loss: 0.0010522191296331584
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00105694 5
# ---------------------------------------------------
# Эпоха: 86 Train loss: 3.575379014364444e-05, Valid loss: 0.0010569416335783899
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00100329 7
# ---------------------------------------------------
# Эпоха: 87 Train loss: 3.9974430728761944e-05, Valid loss: 0.001003288314677775
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00106302 2
# ---------------------------------------------------
# Эпоха: 88 Train loss: 4.3120257760165257e-05, Valid loss: 0.0010630199103616178
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00101627 8
# ---------------------------------------------------
# Эпоха: 89 Train loss: 4.477551756281173e-05, Valid loss: 0.0010162672842852771
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00100883 0
# ---------------------------------------------------
# Эпоха: 90 Train loss: 4.259629313310143e-05, Valid loss: 0.0010088257840834558
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00105881 3
# ---------------------------------------------------
# Эпоха: 91 Train loss: 4.6325773291755466e-05, Valid loss: 0.0010588079458102584
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00100710 7
# ---------------------------------------------------
# Эпоха: 92 Train loss: 5.397003296820912e-05, Valid loss: 0.0010070968128275126
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00104297 2
# ---------------------------------------------------
# Эпоха: 93 Train loss: 4.371869690658059e-05, Valid loss: 0.0010429678368382156
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00105155 1
# ---------------------------------------------------
# Эпоха: 94 Train loss: 4.891240423603449e-05, Valid loss: 0.0010515524772927165
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00097479 6
# ---------------------------------------------------
# Эпоха: 95 Train loss: 4.206452249491122e-05, Valid loss: 0.0009747876902110875
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0009747876902110875 на эпохе 95
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00103031 4
# ---------------------------------------------------
# Эпоха: 96 Train loss: 4.213773609080817e-05, Valid loss: 0.0010303143644705415
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00100852 3
# ---------------------------------------------------
# Эпоха: 97 Train loss: 4.8932653953670524e-05, Valid loss: 0.0010085203684866428
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00100972 6
# ---------------------------------------------------
# Эпоха: 98 Train loss: 4.965650623489637e-05, Valid loss: 0.0010097225313074887
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00097690 0
# ---------------------------------------------------
# Эпоха: 99 Train loss: 4.619610335794277e-05, Valid loss: 0.0009769035677891225
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00102789 4
# ---------------------------------------------------
# Эпоха: 100 Train loss: 4.773726905114017e-05, Valid loss: 0.001027893740683794
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00097975 5
# ---------------------------------------------------
# Эпоха: 101 Train loss: 4.784902193932794e-05, Valid loss: 0.0009797503880690783
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00103141 9
# ---------------------------------------------------
# Эпоха: 102 Train loss: 4.0090836773742924e-05, Valid loss: 0.0010314100654795766
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00100028 1
# ---------------------------------------------------
# Эпоха: 103 Train loss: 3.98083195250365e-05, Valid loss: 0.0010002844501286745
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00101183 0
# ---------------------------------------------------
# Эпоха: 104 Train loss: 4.2804108670679855e-05, Valid loss: 0.0010118320351466537
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00095008 0
# ---------------------------------------------------
# Эпоха: 105 Train loss: 4.8698571845307015e-05, Valid loss: 0.000950075569562614
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.000950075569562614 на эпохе 105
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00099514 1
# ---------------------------------------------------
# Эпоха: 106 Train loss: 5.0408290189807306e-05, Valid loss: 0.0009951389802154154
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00102243 0
# ---------------------------------------------------
# Эпоха: 107 Train loss: 4.86006338178413e-05, Valid loss: 0.0010224326397292316
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00098830 6
# ---------------------------------------------------
# Эпоха: 108 Train loss: 4.005759838037193e-05, Valid loss: 0.000988304236670956
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00094472 3
# ---------------------------------------------------
# Эпоха: 109 Train loss: 4.462516808416695e-05, Valid loss: 0.0009447193006053567
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0009447193006053567 на эпохе 109
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00098221 1
# ---------------------------------------------------
# Эпоха: 110 Train loss: 4.790700040757656e-05, Valid loss: 0.0009822085266932845
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00101695 8
# ---------------------------------------------------
# Эпоха: 111 Train loss: 4.67796951852506e-05, Valid loss: 0.001016948139294982
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00105449 1
# ---------------------------------------------------
# Эпоха: 112 Train loss: 4.48149334260961e-05, Valid loss: 0.0010544899851083755
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00098664 2
# ---------------------------------------------------
# Эпоха: 113 Train loss: 4.69245405838592e-05, Valid loss: 0.0009866413311101496
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00098235 9
# ---------------------------------------------------
# Эпоха: 114 Train loss: 4.618860511982348e-05, Valid loss: 0.000982346769887954
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00098053 6
# ---------------------------------------------------
# Эпоха: 115 Train loss: 4.626009049388813e-05, Valid loss: 0.000980534648988396
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00100329 0
# ---------------------------------------------------
# Эпоха: 116 Train loss: 4.179709212621674e-05, Valid loss: 0.0010032937279902399
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00091228 7
# ---------------------------------------------------
# Эпоха: 117 Train loss: 4.147215477132704e-05, Valid loss: 0.0009122758347075433
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0009122758347075433 на эпохе 117
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00100333 3
# ---------------------------------------------------
# Эпоха: 118 Train loss: 5.182525201234967e-05, Valid loss: 0.001003334007691592
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00098231 9
# ---------------------------------------------------
# Эпоха: 119 Train loss: 4.479173148865812e-05, Valid loss: 0.00098231146694161
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00093426 7
# ---------------------------------------------------
# Эпоха: 120 Train loss: 4.48682194473804e-05, Valid loss: 0.000934261770453304
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00096909 5
# ---------------------------------------------------
# Эпоха: 121 Train loss: 4.985231280443259e-05, Valid loss: 0.0009690886945463717
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00098923 8
# ---------------------------------------------------
# Эпоха: 122 Train loss: 5.757511826232076e-05, Valid loss: 0.000989226158708334
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00094704 2
# ---------------------------------------------------
# Эпоха: 123 Train loss: 4.682224935095292e-05, Valid loss: 0.0009470350632909685
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00097197 7
# ---------------------------------------------------
# Эпоха: 124 Train loss: 4.527275705186184e-05, Valid loss: 0.0009719737863633782
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00098377 7
# ---------------------------------------------------
# Эпоха: 125 Train loss: 4.626898298738524e-05, Valid loss: 0.0009837690158747137
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00099970 0
# ---------------------------------------------------
# Эпоха: 126 Train loss: 4.2801890958799047e-05, Valid loss: 0.0009997047600336373
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00090414 1
# ---------------------------------------------------
# Эпоха: 127 Train loss: 3.91097519241157e-05, Valid loss: 0.0009041437588166445
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0009041437588166445 на эпохе 127
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00090221 9
# ---------------------------------------------------
# Эпоха: 128 Train loss: 3.888662286044564e-05, Valid loss: 0.000902205501915887
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.000902205501915887 на эпохе 128
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00093995 0
# ---------------------------------------------------
# Эпоха: 129 Train loss: 4.0698208977119066e-05, Valid loss: 0.0009399508126080036
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00092533 8
# ---------------------------------------------------
# Эпоха: 130 Train loss: 4.278191718185553e-05, Valid loss: 0.0009253292810171843
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00090022 4
# ---------------------------------------------------
# Эпоха: 131 Train loss: 3.694347706186818e-05, Valid loss: 0.000900219107279554
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.000900219107279554 на эпохе 131
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00096160 2
# ---------------------------------------------------
# Эпоха: 132 Train loss: 4.022499288112158e-05, Valid loss: 0.0009616009483579546
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00095340 1
# ---------------------------------------------------
# Эпоха: 133 Train loss: 3.730633543455042e-05, Valid loss: 0.0009533996926620603
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00091684 2
# ---------------------------------------------------
# Эпоха: 134 Train loss: 3.702485519170295e-05, Valid loss: 0.0009168371616397053
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00095379 7
# ---------------------------------------------------
# Эпоха: 135 Train loss: 3.996595442004036e-05, Valid loss: 0.000953787995968014
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00093670 3
# ---------------------------------------------------
# Эпоха: 136 Train loss: 4.263319624442374e-05, Valid loss: 0.0009366970334667712
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00089494 3
# ---------------------------------------------------
# Эпоха: 137 Train loss: 3.803031777351862e-05, Valid loss: 0.0008949432231020182
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0008949432231020182 на эпохе 137
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00089832 0
# ---------------------------------------------------
# Эпоха: 138 Train loss: 4.0999780139827635e-05, Valid loss: 0.0008983227889984846
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00091338 8
# ---------------------------------------------------
# Эпоха: 139 Train loss: 4.2479864168853966e-05, Valid loss: 0.000913384894374758
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00095084 7
# ---------------------------------------------------
# Эпоха: 140 Train loss: 3.3072562655434015e-05, Valid loss: 0.000950843736063689
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00093110 5
# ---------------------------------------------------
# Эпоха: 141 Train loss: 4.024989812023705e-05, Valid loss: 0.0009311024041380733
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00092647 2
# ---------------------------------------------------
# Эпоха: 142 Train loss: 3.661594837467419e-05, Valid loss: 0.0009264699765481055
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00092219 9
# ---------------------------------------------------
# Эпоха: 143 Train loss: 3.739195544767426e-05, Valid loss: 0.0009221929358318448
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00094612 9
# ---------------------------------------------------
# Эпоха: 144 Train loss: 3.699483077070909e-05, Valid loss: 0.0009461248409934342
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00090326 1
# ---------------------------------------------------
# Эпоха: 145 Train loss: 3.690837911562994e-05, Valid loss: 0.0009032573434524238
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00089537 4
# ---------------------------------------------------
# Эпоха: 146 Train loss: 4.233681447658455e-05, Valid loss: 0.000895374541869387
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00087632 7
# ---------------------------------------------------
# Эпоха: 147 Train loss: 4.496800265769707e-05, Valid loss: 0.0008763198857195675
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0008763198857195675 на эпохе 147
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00089003 9
# ---------------------------------------------------
# Эпоха: 148 Train loss: 3.7985111339366996e-05, Valid loss: 0.0008900271204765886
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00087476 4
# ---------------------------------------------------
# Эпоха: 149 Train loss: 4.3540322258195376e-05, Valid loss: 0.0008747639949433506
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0008747639949433506 на эпохе 149
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00085501 4
# ---------------------------------------------------
# Эпоха: 150 Train loss: 3.874304511555238e-05, Valid loss: 0.0008550136408302933
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0008550136408302933 на эпохе 150
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00087244 9
# ---------------------------------------------------
# Эпоха: 151 Train loss: 4.5085590681992474e-05, Valid loss: 0.0008724417712073773
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00089592 1
# ---------------------------------------------------
# Эпоха: 152 Train loss: 3.8611124909948555e-05, Valid loss: 0.0008959182305261493
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00085942 2
# ---------------------------------------------------
# Эпоха: 153 Train loss: 3.8522602153534535e-05, Valid loss: 0.0008594183309469372
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00090722 9
# ---------------------------------------------------
# Эпоха: 154 Train loss: 3.739314688573358e-05, Valid loss: 0.0009072240209206939
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00086180 7
# ---------------------------------------------------
# Эпоха: 155 Train loss: 3.3266961145272945e-05, Valid loss: 0.0008618049905635417
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00085616 8
# ---------------------------------------------------
# Эпоха: 156 Train loss: 3.888336377713131e-05, Valid loss: 0.0008561594586353749
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00090063 5
# ---------------------------------------------------
# Эпоха: 157 Train loss: 3.905493358615786e-05, Valid loss: 0.0009006260079331696
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00088139 8
# ---------------------------------------------------
# Эпоха: 158 Train loss: 3.288252410129644e-05, Valid loss: 0.000881388783454895
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00091413 8
# ---------------------------------------------------
# Эпоха: 159 Train loss: 3.8078468787716704e-05, Valid loss: 0.0009141270129475743
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00086234 4
# ---------------------------------------------------
# Эпоха: 160 Train loss: 3.4737939313345126e-05, Valid loss: 0.0008623401226941496
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00086856 5
# ---------------------------------------------------
# Эпоха: 161 Train loss: 3.524767089402303e-05, Valid loss: 0.0008685642678756267
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00089210 9
# ---------------------------------------------------
# Эпоха: 162 Train loss: 3.2486085910932164e-05, Valid loss: 0.0008920950058382004
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00086826 2
# ---------------------------------------------------
# Эпоха: 163 Train loss: 3.661911396193318e-05, Valid loss: 0.0008682573679834604
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00085503 5
# ---------------------------------------------------
# Эпоха: 164 Train loss: 4.894631056231447e-05, Valid loss: 0.0008550338679924607
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00085517 7
# ---------------------------------------------------
# Эпоха: 165 Train loss: 3.626558391260915e-05, Valid loss: 0.0008551659702789038
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00089452 1
# ---------------------------------------------------
# Эпоха: 166 Train loss: 4.290528886485845e-05, Valid loss: 0.0008945244189817458
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00080626 3
# ---------------------------------------------------
# Эпоха: 167 Train loss: 3.522663046169327e-05, Valid loss: 0.0008062603592406958
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0008062603592406958 на эпохе 167
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00090200 9
# ---------------------------------------------------
# Эпоха: 168 Train loss: 3.52910650690319e-05, Valid loss: 0.0009019954304676503
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00091410 3
# ---------------------------------------------------
# Эпоха: 169 Train loss: 3.982915077358484e-05, Valid loss: 0.0009141023911070079
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00084108 0
# ---------------------------------------------------
# Эпоха: 170 Train loss: 4.779946120834211e-05, Valid loss: 0.0008410774171352386
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00086761 5
# ---------------------------------------------------
# Эпоха: 171 Train loss: 3.945445096178446e-05, Valid loss: 0.0008676092838868499
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00086335 7
# ---------------------------------------------------
# Эпоха: 172 Train loss: 4.276714826119132e-05, Valid loss: 0.0008633541001472622
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00088372 4
# ---------------------------------------------------
# Эпоха: 173 Train loss: 3.583527031878475e-05, Valid loss: 0.0008837248024065048
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00087017 3
# ---------------------------------------------------
# Эпоха: 174 Train loss: 3.802944211201975e-05, Valid loss: 0.0008701735932845622
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00086788 4
# ---------------------------------------------------
# Эпоха: 175 Train loss: 2.9838586306141225e-05, Valid loss: 0.0008678827725816518
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00084852 1
# ---------------------------------------------------
# Эпоха: 176 Train loss: 3.6710910171677825e-05, Valid loss: 0.0008485192665830255
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00082482 8
# ---------------------------------------------------
# Эпоха: 177 Train loss: 4.0878103391150944e-05, Valid loss: 0.000824824848677963
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00083499 1
# ---------------------------------------------------
# Эпоха: 178 Train loss: 3.570590306480881e-05, Valid loss: 0.0008349931158591062
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00084345 2
# ---------------------------------------------------
# Эпоха: 179 Train loss: 3.8117223812150766e-05, Valid loss: 0.0008434461778961122
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00084277 5
# ---------------------------------------------------
# Эпоха: 180 Train loss: 3.58526533091208e-05, Valid loss: 0.0008427708235103637
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00084503 2
# ---------------------------------------------------
# Эпоха: 181 Train loss: 3.491649713396328e-05, Valid loss: 0.0008450252062175423
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00089076 0
# ---------------------------------------------------
# Эпоха: 182 Train loss: 3.6895951416227037e-05, Valid loss: 0.0008907580049708486
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00084399 8
# ---------------------------------------------------
# Эпоха: 183 Train loss: 3.628314552770462e-05, Valid loss: 0.0008439932717010379
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00082061 1
# ---------------------------------------------------
# Эпоха: 184 Train loss: 3.171287153236335e-05, Valid loss: 0.0008206131460610777
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00083481 0
# ---------------------------------------------------
# Эпоха: 185 Train loss: 3.179518989782082e-05, Valid loss: 0.0008348052215296775
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00079550 9
# ---------------------------------------------------
# Эпоха: 186 Train loss: 3.0792723009653855e-05, Valid loss: 0.0007954968023113906
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0007954968023113906 на эпохе 186
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00083210 2
# ---------------------------------------------------
# Эпоха: 187 Train loss: 3.382488193892641e-05, Valid loss: 0.0008321024943143129
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00081739 1
# ---------------------------------------------------
# Эпоха: 188 Train loss: 3.731097531272099e-05, Valid loss: 0.0008173879759851843
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00083653 5
# ---------------------------------------------------
# Эпоха: 189 Train loss: 3.7254464587022085e-05, Valid loss: 0.0008365275571122766
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00083328 4
# ---------------------------------------------------
# Эпоха: 190 Train loss: 3.2539914354856594e-05, Valid loss: 0.0008332783181685954
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00083450 3
# ---------------------------------------------------
# Эпоха: 191 Train loss: 3.3332702332700134e-05, Valid loss: 0.0008344958478119224
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00082297 0
# ---------------------------------------------------
# Эпоха: 192 Train loss: 3.3003835051204077e-05, Valid loss: 0.000822967616841197
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00083158 7
# ---------------------------------------------------
# Эпоха: 193 Train loss: 3.087264885834884e-05, Valid loss: 0.0008315780141856521
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00081971 2
# ---------------------------------------------------
# Эпоха: 194 Train loss: 4.13227096942137e-05, Valid loss: 0.0008197082206606865
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00083704 5
# ---------------------------------------------------
# Эпоха: 195 Train loss: 3.364821932336781e-05, Valid loss: 0.0008370367577299476
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00083356 7
# ---------------------------------------------------
# Эпоха: 196 Train loss: 3.7668118420697286e-05, Valid loss: 0.0008335602469742298
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00084456 3
# ---------------------------------------------------
# Эпоха: 197 Train loss: 3.083043593505863e-05, Valid loss: 0.0008445627172477543
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00079639 9
# ---------------------------------------------------
# Эпоха: 198 Train loss: 2.889403131121071e-05, Valid loss: 0.0007963929092511535
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00080535 0
# ---------------------------------------------------
# Эпоха: 199 Train loss: 3.1998833947000094e-05, Valid loss: 0.0008053490601014346
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00078917 7
# ---------------------------------------------------
# Эпоха: 200 Train loss: 2.9668111164937726e-05, Valid loss: 0.0007891714631114155
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0007891714631114155 на эпохе 200
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00083862 7
# ---------------------------------------------------
# Эпоха: 201 Train loss: 3.557383224688238e-05, Valid loss: 0.0008386194531340152
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00082384 3
# ---------------------------------------------------
# Эпоха: 202 Train loss: 3.862600933643989e-05, Valid loss: 0.000823838054202497
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00078439 0
# ---------------------------------------------------
# Эпоха: 203 Train loss: 3.7299477480701174e-05, Valid loss: 0.0007843899074941874
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0007843899074941874 на эпохе 203
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00085639 6
# ---------------------------------------------------
# ...
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0005757293256465346 на эпохе 431
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00062527 6
# ---------------------------------------------------
# Эпоха: 432 Train loss: 2.276048089697724e-05, Valid loss: 0.000625274347839877
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00055727 6
# ---------------------------------------------------
# Эпоха: 433 Train loss: 2.305739435541909e-05, Valid loss: 0.000557274091988802
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.000557274091988802 на эпохе 433
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00062495 3
# ---------------------------------------------------
# Эпоха: 434 Train loss: 2.0632282303267858e-05, Valid loss: 0.0006249549333006144
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00059105 1
# ---------------------------------------------------
# Эпоха: 435 Train loss: 2.1214410116954242e-05, Valid loss: 0.0005910450709052384
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00062051 9
# ---------------------------------------------------
# Эпоха: 436 Train loss: 2.218862373410957e-05, Valid loss: 0.000620507140411064
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00060001 0
# ---------------------------------------------------
# Эпоха: 437 Train loss: 2.7495823997014667e-05, Valid loss: 0.000600009283516556
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00062186 3
# ---------------------------------------------------
# Эпоха: 438 Train loss: 2.0334393320808884e-05, Valid loss: 0.0006218585767783225
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00059600 3
# ---------------------------------------------------
# Эпоха: 439 Train loss: 1.8732126500253797e-05, Valid loss: 0.0005959955451544374
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00061283 0
# ---------------------------------------------------
# Эпоха: 440 Train loss: 1.680138184383395e-05, Valid loss: 0.0006128302775323391
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00062194 1
# ---------------------------------------------------
# Эпоха: 441 Train loss: 2.1014493358961773e-05, Valid loss: 0.000621943676378578
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00059425 2
# ---------------------------------------------------
# Эпоха: 442 Train loss: 2.1123844089743215e-05, Valid loss: 0.0005942519928794354
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057772 9
# ---------------------------------------------------
# Эпоха: 443 Train loss: 2.1985988951200852e-05, Valid loss: 0.0005777249461971223
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00058505 9
# ---------------------------------------------------
# Эпоха: 444 Train loss: 2.019215799009544e-05, Valid loss: 0.0005850455490872264
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00061373 8
# ---------------------------------------------------
# Эпоха: 445 Train loss: 2.0780785416718572e-05, Valid loss: 0.0006137257732916623
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00058425 7
# ---------------------------------------------------
# Эпоха: 446 Train loss: 1.9670669735205594e-05, Valid loss: 0.0005842540704179555
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057999 5
# ---------------------------------------------------
# Эпоха: 447 Train loss: 2.035018505921471e-05, Valid loss: 0.0005799938808195293
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00061042 4
# ---------------------------------------------------
# Эпоха: 448 Train loss: 1.8335815366299357e-05, Valid loss: 0.0006104224303271621
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00062797 5
# ---------------------------------------------------
# Эпоха: 449 Train loss: 1.975052618945483e-05, Valid loss: 0.0006279749795794487
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056830 8
# ---------------------------------------------------
# Эпоха: 450 Train loss: 1.8278524566994748e-05, Valid loss: 0.0005683011549990624
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056783 8
# ---------------------------------------------------
# Эпоха: 451 Train loss: 1.7179063161165686e-05, Valid loss: 0.00056783392210491
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057529 0
# ---------------------------------------------------
# Эпоха: 452 Train loss: 1.889956747618271e-05, Valid loss: 0.0005752878205385059
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056221 3
# ---------------------------------------------------
# Эпоха: 453 Train loss: 1.993176992982626e-05, Valid loss: 0.0005622138560283929
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00063313 2
# ---------------------------------------------------
# Эпоха: 454 Train loss: 2.2015978902345524e-05, Valid loss: 0.0006331293843686581
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00059220 9
# ---------------------------------------------------
# Эпоха: 455 Train loss: 2.368822824792005e-05, Valid loss: 0.0005922025593463331
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00060130 1
# ---------------------------------------------------
# Эпоха: 456 Train loss: 1.8613381234899863e-05, Valid loss: 0.0006012961675878614
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00058512 8
# ---------------------------------------------------
# Эпоха: 457 Train loss: 1.8778602589009095e-05, Valid loss: 0.000585119443712756
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00062120 5
# ---------------------------------------------------
# Эпоха: 458 Train loss: 1.7153050885099218e-05, Valid loss: 0.0006212030712049454
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057533 7
# ---------------------------------------------------
# Эпоха: 459 Train loss: 1.8066947359329787e-05, Valid loss: 0.0005753301084041595
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057194 1
# ---------------------------------------------------
# Эпоха: 460 Train loss: 1.6006742498575477e-05, Valid loss: 0.00057193887187168
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00058797 5
# ---------------------------------------------------
# Эпоха: 461 Train loss: 1.9652088758448373e-05, Valid loss: 0.0005879711243323982
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057798 6
# ---------------------------------------------------
# Эпоха: 462 Train loss: 2.69582012151659e-05, Valid loss: 0.0005779778293799609
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00054837 1
# ---------------------------------------------------
# Эпоха: 463 Train loss: 1.810571402529604e-05, Valid loss: 0.0005483722779899836
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0005483722779899836 на эпохе 463
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00056630 8
# ---------------------------------------------------
# Эпоха: 464 Train loss: 2.0183954256935975e-05, Valid loss: 0.0005663008196279407
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00060363 4
# ---------------------------------------------------
# Эпоха: 465 Train loss: 1.8437791368342005e-05, Valid loss: 0.0006036261038389057
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00062080 4
# ---------------------------------------------------
# Эпоха: 466 Train loss: 1.91365480532113e-05, Valid loss: 0.0006208026898093522
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00061212 8
# ---------------------------------------------------
# Эпоха: 467 Train loss: 1.778026371539454e-05, Valid loss: 0.0006121234910096973
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057228 9
# ---------------------------------------------------
# Эпоха: 468 Train loss: 2.0188623147987526e-05, Valid loss: 0.0005722774949390441
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00058164 6
# ---------------------------------------------------
# Эпоха: 469 Train loss: 2.0763431166415103e-05, Valid loss: 0.0005816402845084667
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057057 0
# ---------------------------------------------------
# Эпоха: 470 Train loss: 2.080292506434489e-05, Valid loss: 0.0005705714866053313
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00055776 9
# ---------------------------------------------------
# Эпоха: 471 Train loss: 1.8794571769831236e-05, Valid loss: 0.0005577623378485441
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00053839 8
# ---------------------------------------------------
# Эпоха: 472 Train loss: 2.3076130491972436e-05, Valid loss: 0.0005383852985687554
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0005383852985687554 на эпохе 472
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00057036 4
# ---------------------------------------------------
# Эпоха: 473 Train loss: 1.6138340379256987e-05, Valid loss: 0.0005703611823264509
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056739 0
# ---------------------------------------------------
# Эпоха: 474 Train loss: 1.9603704186010872e-05, Valid loss: 0.0005673873238265514
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057143 0
# ---------------------------------------------------
# Эпоха: 475 Train loss: 1.7902517083712154e-05, Valid loss: 0.0005714260623790324
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057529 0
# ---------------------------------------------------
# Эпоха: 476 Train loss: 1.8004761295742354e-05, Valid loss: 0.0005752941651735455
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056930 3
# ---------------------------------------------------
# Эпоха: 477 Train loss: 1.992939933188609e-05, Valid loss: 0.0005692951381206512
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056901 3
# ---------------------------------------------------
# Эпоха: 478 Train loss: 1.9732759210455696e-05, Valid loss: 0.0005690135003533214
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00058318 0
# ---------------------------------------------------
# Эпоха: 479 Train loss: 2.180353340008878e-05, Valid loss: 0.0005831833113916218
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00058521 0
# ---------------------------------------------------
# Эпоха: 480 Train loss: 2.029970628427691e-05, Valid loss: 0.0005852082394994795
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00054192 1
# ---------------------------------------------------
# Эпоха: 481 Train loss: 1.911376630232553e-05, Valid loss: 0.000541921443073079
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056706 1
# ---------------------------------------------------
# Эпоха: 482 Train loss: 1.810895728340256e-05, Valid loss: 0.0005670645623467863
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00055113 6
# ---------------------------------------------------
# Эпоха: 483 Train loss: 1.6664815302647184e-05, Valid loss: 0.0005511305935215205
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00055668 0
# ---------------------------------------------------
# Эпоха: 484 Train loss: 2.170142124668928e-05, Valid loss: 0.0005566847103182226
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00059009 6
# ---------------------------------------------------
# Эпоха: 485 Train loss: 1.805618476282689e-05, Valid loss: 0.0005900941323488951
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056355 6
# ---------------------------------------------------
# Эпоха: 486 Train loss: 1.8564349829830462e-05, Valid loss: 0.0005635539127979428
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00054091 9
# ---------------------------------------------------
# Эпоха: 487 Train loss: 2.2388891920854803e-05, Valid loss: 0.0005409133445937186
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00055575 5
# ---------------------------------------------------
# Эпоха: 488 Train loss: 2.1254600778775056e-05, Valid loss: 0.0005557541735470295
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00054125 9
# ---------------------------------------------------
# Эпоха: 489 Train loss: 1.999489895752049e-05, Valid loss: 0.0005412533937487751
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00058389 6
# ---------------------------------------------------
# Эпоха: 490 Train loss: 1.9659132249216782e-05, Valid loss: 0.0005838913202751428
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00058619 5
# ---------------------------------------------------
# Эпоха: 491 Train loss: 1.705238591966918e-05, Valid loss: 0.000586193724302575
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00055649 4
# ---------------------------------------------------
# Эпоха: 492 Train loss: 1.784326923370827e-05, Valid loss: 0.0005564908497035503
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00055295 6
# ---------------------------------------------------
# Эпоха: 493 Train loss: 1.826285943025141e-05, Valid loss: 0.000552947778487578
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056920 8
# ---------------------------------------------------
# Эпоха: 494 Train loss: 2.1077429300930818e-05, Valid loss: 0.0005691993865184486
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057505 2
# ---------------------------------------------------
# Эпоха: 495 Train loss: 1.701624833003734e-05, Valid loss: 0.0005750450072810054
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00056455 5
# ---------------------------------------------------
# Эпоха: 496 Train loss: 1.7146804202639034e-05, Valid loss: 0.0005645491182804108
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00052868 6
# ---------------------------------------------------
# Эпоха: 497 Train loss: 1.795655853129574e-05, Valid loss: 0.0005286841769702733
# ---------------------------------------------------
# Минимальная ошибка валидации Valid loss: 0.0005286841769702733 на эпохе 497
# Модель сохранена
# Valid Steps: 2/2  Loss: 0.00055239 8
# ---------------------------------------------------
# Эпоха: 498 Train loss: 2.028244016401004e-05, Valid loss: 0.0005523935542441905
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00059036 5
# ---------------------------------------------------
# Эпоха: 499 Train loss: 1.9748367958527523e-05, Valid loss: 0.0005903553392272443
# ---------------------------------------------------
# Valid Steps: 2/2  Loss: 0.00057060 6
# ---------------------------------------------------
# Эпоха: 500 Train loss: 2.0564075384754688e-05, Valid loss: 0.0005705999210476875
# ---------------------------------------------------
# Обучение завершено
# Всего затрачено времени: 33380.47452521324 c.

# %%
resnet50f = resnet50()
resnet50f.load_state_dict(torch.load('../data/interin/Ac_Fom_2022_WM_scale/restnet50_0_0.pth', map_location=torch.device('cpu')))
resnet50f.cpu()
#resnet50f.cuda()
torch.autograd.set_detect_anomaly(True)
# Out:
# C:\Users\Alexander\AppData\Local\Temp\ipykernel_11036\2429450263.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   resnet50f.load_state_dict(torch.load('../data/interin/Ac_Fom_2022_WM_scale/restnet50_0_0.pth', map_location=torch.device('cpu')))

# %%
start_time = time.time()

#best_network.cuda() 

resnet50f.eval()

predictions = torch.zeros(28, 19, 2).detach()
landmarks = torch.zeros(28, 19, 2).detach()

#images, landmarks = next(iter(test_loader))
counter = 0
print("evaluating on test set")
with torch.no_grad():
    for images, landmark in test_loader:
        images = images.reshape((1,3,224,224))#.cuda()
        landmark = ((landmark + 0.5 )*torch.tensor([224, 224]))#.cuda()  # <- 1280, 1024
        prediction = (resnet50f(images) + 0.5) 
        prediction = prediction.view(19,2)*torch.tensor([224, 224])#.cuda() # <- 1280, 1024
        unorm = UnNormalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
        images = unorm(images).squeeze()
        images = images.permute(1, 2, 0).numpy()
        landmarks[counter,:] = landmark
        predictions[counter,:] = prediction
        predictions.detach()
        counter += 1
endtime = time.time()-start_time
print(endtime)
# Out:
# evaluating on test set
# 2.644915819168091

# %%
plt.imshow(images)
plt.scatter(landmark[:,0],landmark[:,1], color = 'red' , s = 5)
plt.scatter(prediction[:,0],prediction[:,1], color = 'blue' , s = 5)
plt.show()

# %%
difs = abs(predictions - landmarks)
difs = difs.detach()
dis = np.sqrt(difs[:, :,0]**2 + difs[:, :, 1]**2)
av = []
for I in dis:
  av.append(np.mean(I.numpy()))
print(np.mean(av))
print(np.std(av))
# Out:
# 7.1362615
# 2.1993165

# %%
dis.size()
# Out:
# torch.Size([28, 19])

# %%
fig = plt.figure()
plt.boxplot(dis)
plt.xlabel('landmark')
plt.ylabel('pixel distance error')
plt.show()

# %%
difs = abs(predictions - landmarks)
difs = difs.detach()
dis = difs[:, :,0]**2 + difs[:, :, 1]**2
rms = np.sqrt(dis.sum(axis=0)/dis.shape[0])
rms.mean()
# Out:
# tensor(8.3734)

# %%
def procrustes(X, Y, scaling=True, reflection='best'):
    """
    A port of MATLAB's `procrustes` function to Numpy.
    Procrustes analysis determines a linear transformation (translation,
    reflection, orthogonal rotation and scaling) of the points in Y to best
    conform them to the points in matrix X, using the sum of squared errors
    as the goodness of fit criterion.
        d, Z, [tform] = procrustes(X, Y)
    Inputs:
    ------------
    X, Y
        matrices of target and input coordinates. they must have equal
        numbers of  points (rows), but Y may have fewer dimensions
        (columns) than X.
    scaling
        if False, the scaling component of the transformation is forced
        to 1
    reflection
        if 'best' (default), the transformation solution may or may not
        include a reflection component, depending on which fits the data
        best. setting reflection to True or False forces a solution with
        reflection or no reflection respectively.
    Outputs
    ------------
    d
        the residual sum of squared errors, normalized according to a
        measure of the scale of X, ((X - X.mean(0))**2).sum()
    Z
        the matrix of transformed Y-values
    tform
        a dict specifying the rotation, translation and scaling that
        maps X --> Y
    """

    n,m = X.shape
    ny,my = Y.shape

    muX = X.mean(0)
    muY = Y.mean(0)

    X0 = X - muX
    Y0 = Y - muY

    ssX = (X0**2.).sum()
    ssY = (Y0**2.).sum()

    # centred Frobenius norm
    normX = np.sqrt(ssX)
    normY = np.sqrt(ssY)

    # scale to equal (unit) norm
    X0 /= normX
    Y0 /= normY

    if my < m:
        Y0 = np.concatenate((Y0, np.zeros(n, m-my)),0)

    # optimum rotation matrix of Y
    A = np.dot(X0.T, Y0)
    U,s,Vt = np.linalg.svd(A,full_matrices=False)
    V = Vt.T
    T = np.dot(V, U.T)

    if reflection != 'best':

        # does the current solution use a reflection?
        have_reflection = np.linalg.det(T) < 0

        # if that's not what was specified, force another reflection
        if reflection != have_reflection:
            V[:,-1] *= -1
            s[-1] *= -1
            T = np.dot(V, U.T)

    traceTA = s.sum()

    if scaling:

        # optimum scaling of Y
        b = traceTA * normX / normY

        # standarised distance between X and b*Y*T + c
        d = 1 - traceTA**2

        # transformed coords
        Z = normX*traceTA*np.dot(Y0, T) + muX

    else:
        b = 1
        d = 1 + ssY/ssX - 2 * traceTA * normY / normX
        Z = normY*np.dot(Y0, T) + muX

    # transformation matrix
    if my < m:
        T = T[:my,:]
    c = muX - b*np.dot(muY, T)

    #transformation values
    tform = {'rotation':T, 'scale':b, 'translation':c}

    return d, Z, tform
def generalized_procrustes(data):
    mean = data[0,...]
    print('Aligning')
    d = 100
    d_old = 100
    while d > 0.0001:
        d_new = 0
        for i in range(data.shape[0]):
            d_, data[i,:], _ = procrustes(mean, data[i,:], scaling=False, reflection=False)
            d_new += d_ / data.shape[0]
        d = d_old - d_new
        d_old = d_new
        mean = data.mean(axis=0)
    return mean

mean = generalized_procrustes(landmarks)
# Out:
# Aligning

# %%
from scipy.spatial import procrustes as procrustes_ 
procrustes_errors = {'error':[], 'procrustes_disparity':[]}
for i in range(28):
    procrustes_errors['error'].append(av[i])
    mtx1, mtx2, disparity = procrustes_(mean, landmarks[i])
    procrustes_errors['procrustes_disparity'].append(disparity)

# %%
proc = []
#for i in procrustes_errors['procrustes_disparity']:
#    if i>0.001:
#        proc.append(i)
errors = []
for it, i in enumerate(procrustes_errors['error']):
    #$print(it)
    mean_err = np.mean(procrustes_errors['error'])
    mean_disp = np.mean(procrustes_errors['procrustes_disparity'])
    std_err = np.std(procrustes_errors['error'])*2
    std_disp = np.std(procrustes_errors['procrustes_disparity'])*2
    i_p = procrustes_errors['procrustes_disparity'][it]
    if (mean_err - std_err)<i<(mean_err + std_err) and (mean_disp-std_disp)<i_p<(mean_disp + std_disp):
        errors.append(i)
        proc.append(procrustes_errors['procrustes_disparity'][it])

# %%
weights  = proc#procrustes_errors['procrustes_disparity']

heights = errors#procrustes_errors['error']

x = weights#/max(weights)

y = heights#/max(heights)
slope, intercept = np.polyfit(x, y, 1)  # linear model adjustment

y_model = np.polyval([slope, intercept], x)   # modeling...

x_mean = np.mean(x)
y_mean = np.mean(y)
n = len(x)                       # number of samples
m = 2                             # number of parameters
dof = n - m                       # degrees of freedom
t = stats.t.ppf(0.975, dof)       # Students statistic of interval confidence

residual = y - y_model

std_error = (np.sum(residual**2) / dof)**.5   # Standard deviation of the error

# calculating the r2
# https://www.statisticshowto.com/probability-and-statistics/coefficient-of-determination-r-squared/
# Pearson's correlation coefficient
numerator = np.sum((x - x_mean)*(y - y_mean))
denominator = ( np.sum((x - x_mean)**2) * np.sum((y - y_mean)**2) )**.5
correlation_coef = numerator / denominator
r2 = correlation_coef**2

# mean squared error
MSE = 1/n * np.sum( (y - y_model)**2 )

# to plot the adjusted model
x_line = np.linspace(np.min(x), np.max(x), 100)
y_line = np.polyval([slope, intercept], x_line)

# confidence interval
ci = t * std_error * (1/n + (x_line - x_mean)**2 / np.sum((x - x_mean)**2))**.5
# predicting interval
pi = t * std_error * (1 + 1/n + (x_line - x_mean)**2 / np.sum((x - x_mean)**2))**.5  

############### Ploting
plt.rcParams.update({'font.size': 14})
fig = plt.figure()
ax = fig.add_axes([.1, .1, .8, .8])

#, 'o', color = 'royalblue')
ax.plot(x_line, y_line, color = 'royalblue', linewidth=0.1)
ax.fill_between(x_line, y_line + pi, y_line - pi, color = 'lightcyan', label = '95% prediction interval', linewidth=0.1)
ax.fill_between(x_line, y_line + ci, y_line - ci, color = 'skyblue', label = '95% confidence interval')
ax.scatter(x, y, s = 0.6)
ax.set_xlabel('x')
ax.set_ylabel('y')

# rounding and position must be changed for each case and preference
a = str(np.round(intercept))
b = str(np.round(slope,2))
r2s = str(np.round(r2,2))
MSEs = str(np.round(MSE))

#ax.text(45, 110, 'y = ' + a + ' + ' + b + ' x')
#ax.text(45, 100, '$r^2$ = ' + r2s + '     MSE = ' + MSEs)
plt.title('Procrustus disparity vs pixel distance error',  fontsize=12)
plt.ylabel('Avergae pixel distance error',fontsize=9)
plt.xlabel('Procrustus disparity',fontsize=9)
#plt.plot([0,0.6],[0.38,0.38], linewidth=0.5, c='g', label = 'Median average pixel distance error')
#plt.plot([0.118,0.118],[0.0,1], linewidth=0.5, c='r', label = 'Median procrustus disparity')
#plt.legend( fontsize=8)
#plt.xlim([0.0,0.005])
#plt.ylim([0.0,40])
#plt.savefig('linear_reg.png')
print(r2s)
print(b)
# Out:
# 0.01
# 170.65

# %%
plt.hist(procrustes_errors['procrustes_disparity'], bins = 100)
plt.title('Histogram of Procrustes disparities')
plt.xlabel('Procrustes disparity (between predicted and ground truth)')
#plt.xlim((0,0.0012))
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
weights = procrustes_errors['procrustes_disparity']

heights = procrustes_errors['error']
x = weights/max(weights)

y = heights/max(heights)
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
p_value
# Out:
# 0.7357410198968349
